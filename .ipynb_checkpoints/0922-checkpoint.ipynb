# %%
print("大家好")
# Out:
# 大家好

# %%
print("test")
# Out:
# test

# %%
pip list
# Out:
# cryptography                  3.4.8
# cssselect                     1.1.0
# cycler                        0.11.0
# Cython                        0.29.28
# cytoolz                       0.11.0
# daal4py                       2021.5.0
# dask                          2022.2.1
# datashader                    0.13.0
# datashape                     0.5.4
# debugpy                       1.5.1
# decorator                     5.1.1
# defusedxml                    0.7.1
# diff-match-patch              20200713
# distributed                   2022.2.1
# docutils                      0.17.1
# entrypoints                   0.4
# et-xmlfile                    1.1.0
# executing                     0.8.3
# fastjsonschema                2.15.1
# filelock                      3.6.0
# flake8                        3.9.2
# Flask                         1.1.2
# fonttools                     4.25.0
# frozenlist                    1.2.0
# fsspec                        2022.2.0
# ...

# %%
pwd
# Out:
# 'C:\\Users\\user\\dm\\TKU-DM-611630392'

# %%
ls
# Out:
#  磁碟區 C 中的磁碟是 Windows
#  磁碟區序號:  A631-A59D
#
#  C:\Users\user\dm\TKU-DM-611630392 的目錄
#
# 2022/09/29  上午 12:41    <DIR>          .
# 2022/09/28  下午 11:50    <DIR>          ..
# 2022/09/29  上午 12:41    <DIR>          .ipynb_checkpoints
# 2022/09/29  上午 12:21             1,127 0922.ipynb
# 2022/09/29  上午 12:41               718 0923.ipynb
# 2022/09/28  下午 11:50                28 README.md
# 2022/09/28  下午 11:50             1,423 Untitled2.ipynb
# 2022/09/28  下午 11:50             5,459 上課內容.ipynb
#                5 個檔案           8,755 位元組
#                3 個目錄  919,806,357,504 位元組可用

# %%
pip install wget
# Out:
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9675 sha256=777b29885a8ddbaf1418cb129b24157425a370286c98ddaf9de0ffeac4cad8b9
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\04\5f\3e\46cc37c5d698415694d83f607f833f83f0149e49b3af9d0f38
# Successfully built wget
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
import wget

# %%
wget.download("https://github.com/tku-peiyucheng/TKU-DM-Class/blob/main/scores.csv")
# Out:
# -1 / unknown
# 'scores.csv'

# %%
ls
# Out:
#  磁碟區 C 中的磁碟是 Windows
#  磁碟區序號:  A631-A59D
#
#  C:\Users\user\dm\TKU-DM-611630392 的目錄
#
# 2022/09/29  上午 01:01    <DIR>          .
# 2022/09/28  下午 11:50    <DIR>          ..
# 2022/09/29  上午 12:41    <DIR>          .ipynb_checkpoints
# 2022/09/29  上午 01:01            32,856 0922.ipynb
# 2022/09/29  上午 12:41               718 0923.ipynb
# 2022/09/28  下午 11:50                28 README.md
# 2022/09/29  上午 01:01           151,247 scores.csv
# 2022/09/28  下午 11:50             1,423 Untitled2.ipynb
# 2022/09/28  下午 11:50             5,459 上課內容.ipynb
#                6 個檔案         191,731 位元組
#                3 個目錄  919,807,070,208 位元組可用
