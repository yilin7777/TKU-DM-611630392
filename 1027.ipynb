# %%
import pandas as pd
df8=pd.read_csv('covid19.csv')
df8
# Out:
#         country_ch                country_en       cases     deaths
# 0               美國             United States  96,525,344  1,089,942
# 1               印度                     India  44,645,768    528,981
# 2               法國                    France  36,707,566    156,700
# 3               德國                   Germany  35,383,015    152,997
# 4               巴西                    Brazil  34,807,075    687,907
# ..             ...                       ...         ...        ...
# 197  國際運輸工具(鑽石公主號)  Int'l conveyance (Japan)         741         13
# 198             紐埃                      Niue          85          0
# 199             教廷                  Holy See          29          0
# 200            吐瓦魯                    Tuvalu          23          0
# 201             北韓               North Korea           2          1
#
# [202 rows x 4 columns]

# %%
url='https://www.tiobe.com/tiobe-index/'
tables=pd.read_html(url,keep_default_na=False)
tables[0].head(20)
# Out:
#     Oct 2022  Oct 2021 Change Programming Language Programming Language.1  \
# 0          1         1                                             Python
# 1          2         2                                                  C
# 2          3         3                                               Java
# 3          4         4                                                C++
# 4          5         5                                                 C#
# 5          6         6                                       Visual Basic
# 6          7         7                                         JavaScript
# 7          8        10                                  Assembly language
# 8          9         9                                                PHP
# 9         10         8                                                SQL
# 10        11        12                                                 Go
# 11        12        14                                                  R
# ...

# %%
student_url="https://info.tku.edu.tw/basicdata1.aspx"

# %%
student_table=pd.read_html(student_url,encoding='utf-8')
pd.set_option('display.unicode.ambiguous_as_wide', True)
pd.set_option('display.unicode.east_asian_width', True)
pd.set_option('display.width', 100)
student_table
#作業
# Out:
# [                      項目/學年度    108    109    110
#  0                      大學日間部  20273  20239  20763
#  1  大學進修學士班及二年制在職專班   1429   1249   1146
#  2    碩士班、碩士在職專班及博士班   2933   2721   2625
#  3              學生人數合計（人）  24635  24209  24534]

# %%
import requests
result = requests.get("https://info.tku.edu.tw/basicdatal.aspx")
print(result.text)
# Out:
# <html>
#     <head>
#         <title>The resource cannot be found.</title>
#         <style>
#          body {font-family:"Verdana";font-weight:normal;font-size: .7em;color:black;}
#          p {font-family:"Verdana";font-weight:normal;color:black;margin-top: -5px}
#          b {font-family:"Verdana";font-weight:bold;color:black;margin-top: -5px}
#          H1 { font-family:"Verdana";font-weight:normal;font-size:18pt;color:red }
#          H2 { font-family:"Verdana";font-weight:normal;font-size:14pt;color:maroon }
#          pre {font-family:"Lucida Console";font-size: .9em}
#          .marker {font-weight: bold; color: black;text-decoration: none;}
#          .version {color: gray;}
#          .error {margin-bottom: 10px;}
#          .expandable { text-decoration:underline; font-weight:bold; color:navy; cursor:hand; }
#         </style>
#     </head>
#
#     <body bgcolor="white">
#
#             <span><H1>Server Error in '/' Application.<hr width=100% size=1 color=silver></H1>
#
# ...

# %%
stu_url="https://info.tku.edu.tw/in_out_analy2.aspx"
stu_table=pd.read_html(stu_url,encoding='utf-8')
pd.set_option('display.unicode.ambiguous_as_wide', True)
pd.set_option('display.unicode.east_asian_width', True)
pd.set_option('display.width', 100)
stu_table
#作業
# Out:
# [   成本與費用項目/學年度         107                 108                 109
#     成本與費用項目/學年度          元       %          元       %          元       %
#  0             董事會支出     4712199    0.14     5034515    0.14     4806637    0.14
#  1                 人事費     3425297    0.10     3761400    0.11     3761400    0.11
#  2                 業務費      294834    0.01      331545    0.01      221943    0.01
#  3                 維護費       16380    0.00           0    0.00           0    0.00
#  4           出席及交通費      145000    0.00      105000    0.00      115000    0.00
#  5             折舊及攤銷      830688    0.02      836570    0.02      708294    0.02
#  6           行政管理支出   488447613   14.07   504067874   14.35   456937923   13.70
#  7                 人事費   204075154    5.88   202868369    5.77   198804495    5.96
#  8                 業務費   127588638    3.67   120314818    3.42   120503981    3.61
#  9                 維護費    84750314    2.44    96504987    2.75    62266230    1.87
# ...
